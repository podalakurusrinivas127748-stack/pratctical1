# %%
import time

# User input
n = int(input("Enter the number of elements: "))

arr = []
print("Enter the elements:")
for i in range(n):
    arr.append(int(input()))

key = int(input("Enter the element to search: "))

# Start execution time
start = time.perf_counter()

found = -1

# Linear Search
for i in range(n):
    if arr[i] == key:
        found = i
        break

# End execution time
end = time.perf_counter()

# Display result
if found != -1:
    print("Element found at position", found + 1)
else:
    print("Element not found")

print("Execution Time =", end - start, "seconds")
# Out:
# Enter the number of elements: 4
# Enter the elements:
# 12
# 20
# 30
# 50
# Enter the element to search: 20
# Element found at position 2
# Execution Time = 0.0002470220000247991 seconds

# %%
import time

# Binary Search Function
def binary_search(arr, key):
    low = 0
    high = len(arr) - 1

    while low <= high:
        mid = (low + high) // 2

        if arr[mid] == key:
            return mid
        elif arr[mid] < key:
            low = mid + 1
        else:
            high = mid - 1

    return -1


# User Input
n = int(input("Enter the number of elements: "))

print("Enter the elements in sorted order:")
arr = list(map(int, input().split()))

key = int(input("Enter the element to search: "))

# Measure execution time
start_time = time.perf_counter()

index = binary_search(arr, key)

end_time = time.perf_counter()

# Output
if index != -1:
    print(f"Element found at index {index}")
else:
    print("Element not found")

print(f"Execution Time: {end_time - start_time:.10f} seconds")

# Time Complexity
if index != -1 and index == len(arr) // 2:
    print("Best Case Time Complexity: O(1)")
else:
    print("Average/Worst Case Time Complexity: O(log n)")

print("Space Complexity: O(1)")
# Out:
# Enter the number of elements: 4
# Enter the elements in sorted order:
# 10 20 30 40
# Enter the element to search: 30
# Element found at index 2
# Execution Time: 0.0002084030 seconds
# Best Case Time Complexity: O(1)
# Space Complexity: O(1)
