# %%
import time
from collections import deque


# ---------------- BFS ----------------
def bfs(graph, start):
    visited = set()
    queue = deque([start])
    visited.add(start)

    traversal = []

    while queue:
        vertex = queue.popleft()
        traversal.append(vertex)

        for neighbor in graph[vertex]:
            if neighbor not in visited:
                visited.add(neighbor)
                queue.append(neighbor)

    return traversal


# ---------------- DFS ----------------
def dfs(graph, start):
    visited = set()
    traversal = []

    def dfs_recursive(vertex):
        visited.add(vertex)
        traversal.append(vertex)

        for neighbor in graph[vertex]:
            if neighbor not in visited:
                dfs_recursive(neighbor)

    dfs_recursive(start)
    return traversal


# ---------------- User Input ----------------

graph = {}

n = int(input("Enter number of vertices: "))

# Create vertices
for i in range(n):
    graph[i] = []

edges = int(input("Enter number of edges: "))

print("Enter edges (u v):")
for i in range(edges):
    u, v = map(int, input().split())

    # Undirected graph
    graph[u].append(v)
    graph[v].append(u)

start = int(input("Enter starting vertex: "))


# ---------------- BFS Execution ----------------

start_time = time.perf_counter()

bfs_result = bfs(graph, start)

end_time = time.perf_counter()

bfs_time = end_time - start_time

print("\nBFS Traversal:")
print(" -> ".join(map(str, bfs_result)))
print(f"BFS Execution Time: {bfs_time:.10f} seconds")


# ---------------- DFS Execution ----------------

start_time = time.perf_counter()

dfs_result = dfs(graph, start)

end_time = time.perf_counter()

dfs_time = end_time - start_time

print("\nDFS Traversal:")
print(" -> ".join(map(str, dfs_result)))
print(f"DFS Execution Time: {dfs_time:.10f} seconds")
# Out:
# Enter number of vertices: 6
# Enter number of edges: 7
# Enter edges (u v):
# 0 1
# 0 2
# 1 3
# 1 4
# 2 4
# 3 5
# 4 5
# Enter starting vertex: 0
#
# BFS Traversal:
# 0 -> 1 -> 2 -> 3 -> 4 -> 5
# BFS Execution Time: 0.0001025010 seconds
#
# DFS Traversal:
# 0 -> 1 -> 3 -> 5 -> 4 -> 2
# DFS Execution Time: 0.0001080910 seconds
