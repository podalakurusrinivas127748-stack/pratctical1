# %%
import time


def knapsack(n, capacity, weights, values):
    # DP table
    dp = [[0 for _ in range(capacity + 1)] for _ in range(n + 1)]

    for i in range(1, n + 1):
        for w in range(1, capacity + 1):

            if weights[i - 1] <= w:
                dp[i][w] = max(
                    values[i - 1] + dp[i - 1][w - weights[i - 1]],
                    dp[i - 1][w]
                )
            else:
                dp[i][w] = dp[i - 1][w]

    return dp[n][capacity]


# User input
n = int(input("Enter number of items: "))

weights = list(map(int, input(
    f"Enter weights of {n} items: "
).split()))

values = list(map(int, input(
    f"Enter values of {n} items: "
).split()))

capacity = int(input("Enter knapsack capacity: "))


# Start execution time
start_time = time.perf_counter()

# Solve Knapsack
maximum_profit = knapsack(n, capacity, weights, values)

# End execution time
end_time = time.perf_counter()


# Calculate execution time
execution_time = (end_time - start_time) * 1000


# Output
print("\nMaximum Profit =", maximum_profit)
print("Execution Time = {:.6f} milliseconds".format(execution_time))
print("Time Complexity = O(n * W)")
print("Space Complexity = O(n * W)")
# Out:
# Enter number of items: 5
# Enter weights of 5 items: 1 4 6 8 5
# Enter values of 5 items: 10 20 30 40 60
# Enter knapsack capacity: 6
#
# Maximum Profit = 70
# Execution Time = 0.144030 milliseconds
# Time Complexity = O(n * W)
# Space Complexity = O(n * W)
